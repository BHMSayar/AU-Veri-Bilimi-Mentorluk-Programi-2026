# %% [markdown]
# ## VARIABLES

# %%
x = 19

# %%
type(x)
# Out:
# int

# %%
y = 11.2

# %%
type(y)
# Out:
# float

# %%
z = "Ayberk Şilen"

# %%
type(z)
# Out:
# str

# %%
print(x * y + len(z))
# Out:
# 27

# %% [markdown]
# ## STRING METHODS

# %%
isim = "ayberk"

# %%
soyIsim = "şilen"

# %%
isimSoyisim = isim.capitalize() + " " + soyIsim.capitalize()

# %%
print(isimSoyisim)
# Out:
# Ayberk Şilen

# %% [markdown]
# ## SLICING

# %%
karisikString = "Ayberk Şilen"

# %%
print(karisikString[3:])
# Out:
# erk Şilen

# %%
print(karisikString[-1:])
# Out:
# n

# %%
print(karisikString[:-3])
# Out:
# Ayberk Şi

# %%
print(karisikString[::-1])
# Out:
# neliŞ krebyA

# %%
print(karisikString[2:11:5])
# Out:
# bŞ

# %% [markdown]
# ## LISTS

# %%
list1 = [124,433,4324314,55,434]

# %%
print(list1)
# Out:
# [124, 433, 4324314, 55, 434]

# %%
liste1.append(50)

# %%
print(list1)
# Out:
# [124, 433, 4324314, 55, 434]

# %%
print(list1[4])
# Out:
# 434

# %%
carBrands = ["Mercedes", "Audi" , "BMW" , "Aston Martin"]

# %%
print(carBrands)
# Out:
# ['Mercedes', 'Audi', 'BMW', 'Aston Martin']

# %%
print(carBrands[2])
# Out:
# BMW

# %%
carBrands.append("Porsche")

# %%
print(carBrands)
# Out:
# ['Mercedes', 'Audi', 'BMW', 'Aston Martin', 'Porsche']

# %%
carBrands.remove("BMW")

# %%
print(carBrands)
# Out:
# ['Mercedes', 'Audi', 'Aston Martin', 'Porsche']

# %%
carBrands.reverse()

# %%
carBrands
# Out:
# ['Porsche', 'Aston Martin', 'Audi', 'Mercedes']

# %%
nestedList = [1,2.5,"dgkmalgdmgs",32131,[55,"3"]]

# %%
str3 = nestedList[4][1]

# %%
print(str3)
# Out:
# 3

# %% [markdown]
# ## DICTIONARY

# %%
carPrices = {"Audi" : 100000 , "Fiat" : 10000 , "Rolls-Royce" : 300000}

# %%
print(carPrices.keys())
# Out:
# dict_keys(['Audi', 'Fiat', 'Rolls-Royce'])

# %%
print(carPrices.values())
# Out:
# dict_values([100000, 10000, 300000])

# %%
print(carPrices["Fiat"])
# Out:
# 10000

# %% [markdown]
# ## SET

# %%
newSet = {1,2,1,4,5,666, 555,666,4,421,1}

# %%
type(newSet)
# Out:
# set

# %%
newSet
# Out:
# {1, 2, 4, 5, 421, 555, 666}

# %%
newSet.add(1223)

# %%
newSet
# Out:
# {1, 2, 4, 5, 421, 555, 666, 1223}

# %% [markdown]
# ## BOOL AND COMPARISONS

# %%
x = 5

# %%
y = 2.5

# %%
x <= y
# Out:
# False

# %%
x > y
# Out:
# True

# %%
x < -420 and y > 44
# Out:
# False

# %%
x < 101 or y >= 2
# Out:
# True

# %%
not x == 5
# Out:
# False
