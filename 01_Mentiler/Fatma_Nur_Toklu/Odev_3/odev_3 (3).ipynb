# %%
import numpy as np
import time

# %%
dataSize = 5000000

# %%
list1 = list(range(dataSize))
list2 = list(range(dataSize))

array1 = np.arange(dataSize)
array2 = np.arange(dataSize)

# %%
startList = time.time()
resultsList = []

# %%
for i in range(dataSize) :
    results.append(list1[i] + list2[i])

# %%
endList = time.time()
timePassList = endList - startList
print(f"Klasik Python Süresi: {timePassList:.4f} saniye")
# Out:
# Klasik Python Süresi: 1091.1077 saniye

# %%
startArray = time.time()

# %%
resultsArray = array1 + array2

# %%
endArray = time.time()

# %%
timePassArray = endArray - startArray

# %%
print(f"NumPy Süresi: {timePassArray:.4f} saniye")
# Out:
# NumPy Süresi: 0.3983 saniye

# %%
difference = timePassList / timePassArray
print(f"SONUÇ: NumPy, klasik döngüden yaklaşık {difference:.2f} kat daha hızlı!")
# Out:
# SONUÇ: NumPy, klasik döngüden yaklaşık 2739.54 kat daha hızlı!
