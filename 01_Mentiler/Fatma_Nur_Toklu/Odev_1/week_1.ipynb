# %% [markdown]
# ## Variables

# %%
myVar = 12
myOtherVar = 13

# %% [markdown]
# Interger

# %%
myVar + myOtherVar
# Out:
# 25

# %%
type(myVar)
# Out:
# int

# %% [markdown]
# Float

# %%
result = myOtherVar / myVar

# %%
result
# Out:
# 1.0833333333333333

# %%
type(result)
# Out:
# float

# %%
a = 5
b = 3.14
sum = a + b
type(sum)
# Out:
# float

# %%
sum
# Out:
# 8.14

# %% [markdown]
# ## Mathematical Operations

# %%
4 ** 2
# Out:
# 16

# %%
# Remainder
93 % 4
# Out:
# 1

# %%
age = input("Please enter your age: ")
# Out:
# Please enter your age:  21

# %%
age
# Out:
# '21'

# %%
type(age)
# Out:
# str

# %% [markdown]
# ## String

# %%
y = "hello world"

# %%
y.capitalize()
# Out:
# 'Hello world'

# %%
nur = "merhaba benim ismim nur ve 21 yaşındayım."

# %%
nur.split()
# Out:
# ['merhaba', 'benim', 'ismim', 'nur', 've', '21', 'yaşındayım.']

# %%
intAge = int(age)
type(intAge)
# Out:
# int

# %%
surname = "TOKLU"
len(surname)
# Out:
# 5

# %%
## slicing
surname[-1]
nur[3 : : 2]
# Out:
# 'hb ei si u e2 aıdym'

# %% [markdown]
# ## List

# %%
myList = ["fındık", "köpek", 18, "karabiber", 65, "kumpir", "flapi", 23.5]

# %%
myList[1] = "sütlaç"
myList.append("kaş")
myList
# Out:
# ['fındık', 'sütlaç', 18, 'karabiber', 65, 'kumpir', 'flapi', 23.5, 'kaş']

# %%
myList.pop(4)
# Out:
# 65

# %%
myList
# Out:
# ['fındık', 'sütlaç', 18, 'karabiber', 'kumpir', 'flapi', 23.5, 'kaş']

# %%
myOtherList = [21, "tiramisu", "kalp", 10]
sumOfLists = myList + myOtherList

# %%
sumOfLists
# Out:
# ['fındık',
#  'sütlaç',
#  18,
#  'karabiber',
#  'kumpir',
#  'flapi',
#  23.5,
#  'kaş',
#  21,
#  'tiramisu',
#  'kalp',
#  10]

# %%
nestedList = ["karamel", "vanilya", [2, 1]]

# %%
myElement = nestedList[2][1]
myElement
# Out:
# 1

# %% [markdown]
# ## Dictionary

# %%
## key-value pairing
myDict = {"Antalya" : 7, "Ankara" : 6, "Konya" : 42, "İstanbul" : 34}
myDict["Antalya"]
# Out:
# 7

# %%
myDict.keys()
# Out:
# dict_keys(['Antalya', 'Ankara', 'Konya', 'İstanbul'])
